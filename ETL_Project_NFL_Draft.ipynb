# %%
#Dependices
import pandas as pd
from sqlalchemy import create_engine

# %% [markdown]
# ## Store CVS into data frame

# %%
csv_file = 'NFLDRAFT20092019_ETL.csv'
NFL_data_df = pd.read_csv(csv_file)
NFL_data_df
# Out:
#       Draft year Round  Pick                  Team            Player   \
# 0           2009     1     1         Detroit Lions   Matthew Stafford
# 1           2009     1     2        St. Louis Rams        Jason Smith
# 2           2009     1     3    Kansas City Chiefs      Tyson Jackson
# 3           2009     1     4      Seattle Seahawks        Aaron Curry
# 4           2009     1     5         New York Jets       Mark Sanchez
# ...          ...   ...   ...                   ...                ...
# 2797        2019     7   252        Denver Broncos       Josh Furman
# 2798        2019     7   253  New England Patriots   Xzavier Dickson
# 2799        2019     7   254   San Francisco 49ers     Rory Anderson
# 2800        2019     7   255    Indianapolis Colts     Denzelle Good
# 2801        2019     7   256     Arizona Cardinals  Gerald Christian
#
#      Position         College Conference                   Notes
# 0          QB         Georgia        SEC                       0
# 1          OT          Baylor     Big 12                       0
# 2          DE             LSU        SEC                       0
# 3          LB     Wake Forest        ACC                       0
# 4          QB             USC     Pac-10  from Cleveland[R1 - 1]
# ...       ...             ...        ...                     ...
# 2797        S  Oklahoma State     Big 12                       0
# 2798       LB         Alabama        SEC                       0
# 2799       TE  South Carolina        SEC                       0
# 2800       OT       Mars Hill        SAC                       0
# 2801       TE      Louisville        ACC          Mr. Irrelevant
#
# [2802 rows x 9 columns]

# %% [markdown]
# ## Create data frame with select columns

# %%
NFL_data_pd.columns
# Out:
# Index(['Draft year', 'Round', 'Pick', 'Team', 'Player ', 'Position', 'College',
#        'Conference', 'Notes', '0', 'Unnamed: 10'],
#       dtype='object')

# %%
# We only want Draft data relating to first round and conference, so create a new table that 
#takes all the columns relating to that information 
New_NFL_data_pd = NFL_data_df[["Draft year", "Round", "Player ", "Position",
                            "Conference"]]
New_NFL_data_pd
# Out:
#       Draft year Round            Player  Position Conference
# 0           2009     1   Matthew Stafford       QB        SEC
# 1           2009     1        Jason Smith       OT     Big 12
# 2           2009     1      Tyson Jackson       DE        SEC
# 3           2009     1        Aaron Curry       LB        ACC
# 4           2009     1       Mark Sanchez       QB     Pac-10
# ...          ...   ...                ...      ...        ...
# 2797        2019     7       Josh Furman         S     Big 12
# 2798        2019     7   Xzavier Dickson        LB        SEC
# 2799        2019     7     Rory Anderson        TE        SEC
# 2800        2019     7     Denzelle Good        OT        SAC
# 2801        2019     7  Gerald Christian        TE        ACC
#
# [2802 rows x 5 columns]

# %% [markdown]
# ## Get needed info - CHANGE TITLE

# %%
New_NFL_data_pd.to_csv('New_NFL_data_pd.csv', index=False)

# %%
# We only like 1st rounders, so find those that scored is = 1, 
#first_round_df = NFL_data_df.loc[NFL_data_df["Round"] == str(1), [
   # "Draft year", "Player ", "Position", "Conference"]]
#first_round_df
# Extract rows corresponding only to first rounders
first_rounder = New_NFL_data_pd.loc[New_NFL_data_pd["Round"] == "1"]
first_rounder.head(150)
# Out:
#       Draft year Round           Player  Position  Conference
# 0           2009     1  Matthew Stafford       QB         SEC
# 1           2009     1       Jason Smith       OT      Big 12
# 2           2009     1     Tyson Jackson       DE         SEC
# 3           2009     1       Aaron Curry       LB         ACC
# 4           2009     1      Mark Sanchez       QB      Pac-10
# ...          ...   ...               ...      ...         ...
# 1035        2013     1         Eric Reid        S         SEC
# 1036        2013     1       Justin Pugh       OT    Big East
# 1037        2013     1         Kyle Long        G      Pac-12
# 1038        2013     1      Tyler Eifert       TE  Ind. (FBS)
# 1039        2013     1   Desmond Trufant       CB      Pac-12
#
# [150 rows x 5 columns]

# %%
# Count how many sightings have occured within each state
Conference_counts_pd = first_round_df["Conference"].value_counts()
Conference_counts.head()
# Out:
# SEC        101
# ACC         58
# Big Ten     45
# Pac-12      44
# Big 12      43
# Name: Conference, dtype: int64

# %%
print(Conference_counts)
# Out:
# SEC             101
# ACC              58
# Big Ten          45
# Pac-12           44
# Big 12           43
# The American     12
# Big East         10
# Pac-10            9
# Ind. (FBS)        9
# MAC               6
# MW                5
# C-USA             4
# WAC               3
# MWC               1
# MVFC              1
# Name: Conference, dtype: int64
